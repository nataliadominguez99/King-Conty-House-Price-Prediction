# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset of country houses from a CSV file into a pandas DataFrame
country_houses = pd.read_csv(r"C:\DSML bootcamp\Week5\Project\king_ country_ houses_aa.csv")

# %% [markdown]
# ##### <span style="color:#FFD600"> Exploring the data

# %%
# Display the first 5 rows of the 'country_houses' DataFrame
country_houses.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# Return the dimensions of the 'country_houses' DataFrame
country_houses.shape
# Out:
# (21613, 21)

# %%
# Display a concise summary of the 'country_houses' DataFrame
country_houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
# Generate descriptive statistics for the numeric columns in the 'country_houses' DataFrame
country_houses.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ##### <span style="color:#FFD600"> Data Cleaning (null values, duplicates, unique values, data types)

# %%
# Check for missing values in the 'country_houses' DataFrame
country_houses.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
# Display the data type of each column in the 'country_houses' DataFrame
country_houses.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
# Return the number of unique values in each column of the 'country_houses' DataFrame
country_houses.nunique()
# Out:
# id               21436
# date               372
# price             4028
# bedrooms            13
# bathrooms           30
# sqft_living       1038
# sqft_lot          9782
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               12
# sqft_above         946
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5034
# long               752
# sqft_living15      777
# sqft_lot15        8689
# dtype: int64

# %%
#changed date objet to date format
country_houses["date"] = pd.to_datetime(country_houses["date"])
country_houses["date"]
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21608   2014-05-21
# 21609   2015-02-23
# 21610   2014-06-23
# 21611   2015-01-16
# 21612   2014-10-15
# Name: date, Length: 21613, dtype: datetime64[ns]

# %%
# Check for duplicate rows in the 'country_houses' DataFrame
country_houses.duplicated().sum()
# Out:
# np.int64(0)

# %%
# because id should not have duplicates, it has to be unique, key of the table
country_houses["id"].duplicated().sum()
# Out:
# np.int64(177)

# %%
# Identify duplicate 'id' values in the 'country_houses' DataFrame
dup_ids = country_houses[country_houses["id"].duplicated()]["id"]

# Print the duplicated IDs
print("Duplicated IDs:")
print(dup_ids.unique())
# Out:
# Duplicated IDs:
# [6021501535 4139480200 7520000520 3969300030 2231500030 8820903380
#   726049190 8682262400 9834200885 8062900070 1231000510 6117501820
#  2228900270 3630120700 7888000390 2143700830 3395040550 4345000510
#  9407110710    1000102 1781500435 1232000810 7856400240 7983000200
#  9136103130 5083000375 7409700215 1823049202 2767602141 1254200015
#   723049156 4435000705 4364700600 1825069031 3262300940 9353300600
#  1524079093 9809000020 3303000130 7524400250 4204400098 6632900574
#  2726049071 3578401060 1788800630 6381500170 1954420170 1545800290
#  9828200460 9222400605 8832900780 8645530010 3323059027 5417600130
#  8651510380 5249801440  526059224 1446403850  251300110 4139420590
#  2621600015 2206700215 2787460720 3883800011 4154300296 1721801010
#  1237500540 5101405604 5127001320 5282200015 7977201065 3739500096
#  1568100300 1922059278  302000375  722039087 8129700644 4443800385
#  2212200100 4302201085 5054800110 8103000110 2568300045 3598600049
# ...

# %%
# Retrieve all rows in 'country_houses' that have duplicated 'id' values
dup_rows = country_houses[country_houses["id"].duplicated(keep=False)]
dup_rows
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 93     6021501535 2014-07-25   430000.0         3       1.50         1580
# 94     6021501535 2014-12-23   700000.0         3       1.50         1580
# 313    4139480200 2014-06-18  1384000.0         4       3.25         4290
# 314    4139480200 2014-12-09  1400000.0         4       3.25         4290
# 324    7520000520 2014-09-05   232000.0         2       1.00         1240
# ...           ...        ...        ...       ...        ...          ...
# 20670  8564860270 2015-03-30   502000.0         4       2.50         2680
# 20779  6300000226 2014-06-26   240000.0         4       1.00         1200
# 20780  6300000226 2015-05-04   380000.0         4       1.00         1200
# 21580  7853420110 2014-10-03   594866.0         3       3.00         2780
# 21581  7853420110 2015-05-04   625000.0         3       3.00         2780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
# Sort rows by date and remove duplicate IDs,
# keeping only the most recent record for each ID
df_clean = country_houses.sort_values("date").drop_duplicates(subset="id", keep="last")
df_clean
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 16768  5561000190 2014-05-02   437500.0         3       2.25         1970
# 9596    472000620 2014-05-02   790000.0         3       2.50         2600
# 9587   1024069009 2014-05-02   675000.0         5       2.50         2820
# 20602  7853361370 2014-05-02   555000.0         4       2.50         3310
# 11577  5056500260 2014-05-02   440000.0         4       2.25         2160
# ...           ...        ...        ...       ...        ...          ...
# 7898   1422700040 2015-05-14   183000.0         3       1.00         1170
# 928    8730000270 2015-05-14   359000.0         2       2.75         1370
# 5637   7923600250 2015-05-15   450000.0         5       2.00         1870
# 13053  5101400871 2015-05-24   445500.0         2       1.75         1390
# 16594  9106000005 2015-05-27  1310000.0         4       2.25         3750
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %% [markdown]
# ##### <span style="color:#FFD600">EDA focused on data preprocessing:

# %% [markdown]
# <span style="color:#FFE5B4">
# Explore the distribution of your data (features and target); explore correlations with the target and multicollinearity (at this point, just explore and comment, so that you know what can be done to improve the model on the data side later on - after running a baseline model).

# %%
# Compute correlations between features (excluding id and date)
corr_all = country_houses.drop(columns=["id", "date"]).corr()

# Create a mask to hide the upper triangle (avoid duplicate values)
mask = np.triu(np.ones_like(corr_all, dtype=bool))

# Plot a heatmap of correlations
plt.figure(figsize=(18,10))
sns.heatmap(
    corr_all,
    mask=mask,       # apply mask
    annot=True,      # show correlation values
    cmap="coolwarm", # color scale
    center=0,        # center around 0
    fmt=".2f"        # format decimals
)
plt.title("Feature correlations")
plt.show()

# %%
# Histogram of house prices
plt.figure(figsize=(6,4))
sns.histplot(country_houses['price'])
plt.title("House Price Distribution")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

# Histogram with log scale (zoom in on lower range)
plt.figure(figsize=(6,4))
sns.histplot(country_houses['price'], log_scale=True)
plt.title("House Price Distribution (log scale)")
plt.xlabel("Price (log)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### <span style="color:#FFD600">X-y Split

# %%
# Import function to split data into training and test sets
from sklearn.model_selection import train_test_split

# %% [markdown]
# <span style="color:#E6B3FF"> All Data

# %%
# Features: all columns except price, id, and date
X_data = country_houses.drop(columns=["price", "id", "date"])

# Target: the house price
y_data = country_houses["price"]

# %%
# Split data into train (80%) and test (20%) sets
X_train_data, X_test_data, y_train_data, y_test_data = train_test_split(
    country_houses.drop(columns=["price","id","date"]),  # features
    country_houses["price"],                             # target
    test_size=0.2,                                       # 20% for testing
    random_state=42                                      # reproducibility
)

# %% [markdown]
# <span style="color:#E6B3FF"> Dropping Data

# %%
# Features from cleaned data (exclude price, id, date)
X_data_drop = df_clean.drop(columns=["price", "id", "date"])

# Target: price from cleaned data
y_data_drop = df_clean["price"]

# %%
# Split cleaned data into train (80%) and test (20%) sets
X_train_drop, X_test_drop, y_train_drop, y_test_drop = train_test_split(
    df_clean.drop(columns=["price","id","date"]),  # features
    df_clean["price"],                             # target
    test_size=0.2,                                 # 20% test
    random_state=42                                # reproducible split
)

# %% [markdown]
# ##### <span style="color:#FFD600">Handle categorical variables (encoding)

# %% [markdown]
# Not neccesary in this project.

# %% [markdown]
# ##### <span style="color:#FFD600">Modeling

# %% [markdown]
# <span style="color:#FFE5B4">(train-test split; training the model with .fit(); generating predictions with .predict() for the training and testing set; evaluating the predictions using metrics): select at least 3 models to try and compare the results.

# %%
# Import regression models and evaluation metrics
from sklearn.linear_model import LinearRegression           # Linear regression model
from sklearn.metrics import mean_squared_error, r2_score     # Metrics for model performance
from sklearn.ensemble import AdaBoostRegressor              # Ensemble boosting regressor
import xgboost as xgb                                       # XGBoost regressor
from sklearn.ensemble import RandomForestRegressor          # Random forest regressor
from sklearn.ensemble import GradientBoostingRegressor      # Gradient boosting regressor
from catboost import CatBoostRegressor                      # Cat boosting regressor

# %% [markdown]
# <span style="color:#B3FFB3"> All Data

# %% [markdown]
# <span style="color:#E6B3FF"> Linear Regression

# %%
# Create and train a linear regression model
linear_model = LinearRegression()
linear_model.fit(X_train_data, y_train_data)  # fit model to training data
# Out:
# LinearRegression()

# %%
# Make predictions using the trained linear regression model
y_test_pred_data = linear_model.predict(X_test_data)    # predictions on test set
y_train_pred_data = linear_model.predict(X_train_data)  # predictions on train set

# %%
# Evaluate model performance using R² score
print("R2 Linear Regression Train:", f"{r2_score(y_train_data, y_train_pred_data):.5f}") # training set
print("R2 Linear Regression Test:", f"{r2_score(y_test_data, y_test_pred_data):.5f}")    # test set
# Out:
# R2 Linear Regression Train: 0.69910
# R2 Linear Regression Test: 0.70119

# %% [markdown]
# <span style="color:#E6B3FF"> ADAboosting

# %%
# Create and train an AdaBoost regression model
abc = AdaBoostRegressor(n_estimators=100, learning_rate=0.05, random_state=42)
model = abc.fit(X_train_data, y_train_data)  # fit model to training data

# %%
# Make predictions with the trained AdaBoost model
y_test_pred_data = model.predict(X_test_data)    # predictions on test set
y_train_pred_data = model.predict(X_train_data)  # predictions on train set

# %%
# Evaluate AdaBoost model performance using R² score
print("R2 ADAregressor Train:", f"{r2_score(y_train_data, y_train_pred_data):.5f}")  # train set
print("R2 ADAregressor Test:", f"{r2_score(y_test_data, y_test_pred_data):.5f}")    # test set
# Out:
# R2 ADAregressor Train: 0.70886
# R2 ADAregressor Test: 0.65693

# %% [markdown]
# <span style="color:#E6B3FF"> XGboosting

# %%
# Create and train an XGBoost regression model
xgb_reg = xgb.XGBRegressor()
xgb_reg.fit(X_train_data, y_train_data)  # fit model to training data
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
# Make predictions with the trained XGBoost model
y_test_pred_data = xgb_reg.predict(X_test_data)    # test set predictions
y_train_pred_data = xgb_reg.predict(X_train_data)  # train set predictions

# %%
# Evaluate XGBoost model performance using R² score
print("R2 XGboost Train:", f"{r2_score(y_train_data, y_train_pred_data):.5f}")  # train set
print("R2 XGboost Test:", f"{r2_score(y_test_data, y_test_pred_data):.5f}")    # test set
# Out:
# R2 XGboost Train: 0.97646
# R2 XGboost Test: 0.85513

# %% [markdown]
# <span style="color:#E6B3FF"> Random Forest

# %%
# Create and train a Random Forest regression model
rf_regressor = RandomForestRegressor(n_estimators=120, random_state=42)
rf_regressor.fit(X_train_data, y_train_data)  # fit model to training data
# Out:
# RandomForestRegressor(n_estimators=120, random_state=42)

# %%
# Predict with Random Forest and calculate MSE
y_test_pred_data = rf_regressor.predict(X_test_data)       # test set predictions
mse_test = mean_squared_error(y_test_data, y_test_pred_data)  # test set MSE

y_train_pred_data = rf_regressor.predict(X_train_data)     # train set predictions
mse_train = mean_squared_error(y_train_data, y_train_pred_data)  # train set MSE

# %%
# Display training error and performance for Random Forest
print(f"Mean Squared Error: {mse_train:.2f}")                        # training MSE
print("R2 Random Forest Train:", f"{r2_score(y_train_data, y_train_pred_data):.5f}")  # training R²
# Out:
# Mean Squared Error: 2228496940.85
# R2 Random Forest Train: 0.98294

# %%
# Display test error and performance for Random Forest
print(f"Mean Squared Error: {mse_test:.2f}")                     # test set MSE
print("R2 Random Forest Test:", f"{r2_score(y_test_data, y_test_pred_data):.5f}")  # test set R²
# Out:
# Mean Squared Error: 21807588291.06
# R2 Random Forest Test: 0.85575

# %%
print("R2 Random Forest Train:", f"{r2_score(y_train_data, y_train_pred_data):.5f}")  # training R²
print("R2 Random Forest Test:", f"{r2_score(y_test_data, y_test_pred_data):.5f}")  # test set R²
# Out:
# R2 Random Forest Train: 0.98294
# R2 Random Forest Test: 0.85575

# %% [markdown]
# <span style="color:#E6B3FF"> Gradient Boosting

# %%
# Create and train a Gradient Boosting regression model
gbr = GradientBoostingRegressor(
    loss='absolute_error',  # use MAE as loss function
    learning_rate=0.1,
    n_estimators=300,
    max_depth=1,
    max_features=5,
    random_state=42
)
gbr.fit(X_train_data, y_train_data)  # fit model to training data
# Out:
# GradientBoostingRegressor(loss='absolute_error', max_depth=1, max_features=5,
#                           n_estimators=300, random_state=42)

# %%
# Make predictions with the trained Gradient Boosting model
y_test_pred_drop = gbr.predict(X_test_data)     # test set predictions
y_train_pred_drop = gbr.predict(X_train_data)   # train set predictions

# %%
# Compute Root Mean Squared Error (RMSE) for train and test sets
train_rmse = mean_squared_error(y_train_data, y_train_pred_data) ** 0.5  # training RMSE
test_rmse  = mean_squared_error(y_test_data, y_test_pred_data) ** 0.5   # test RMSE

# %%
# Evaluate Gradient Boosting model performance using R² score
print("R2 Gradient Train:", f"{r2_score(y_train_data, y_train_pred_data):.5f}")  # train set
print("R2 Gradient Test:", f"{r2_score(y_test_data, y_test_pred_data):.5f}")    # test set
# Out:
# R2 Gradient Train: 0.98294
# R2 Gradient Test: 0.85575

# %% [markdown]
# <span style="color:#E6B3FF"> CatBoost

# %%
# Initialize CatBoost Regressor with no training logs (verbose=0) and fixed random seed for reproducibility
cat = CatBoostRegressor(verbose=0, random_state=42)

# Train the model on the training set
cat.fit(X_train_data, y_train_data)

# %%
# Predicciones en train y test con CatBoost
y_test_pred_data = cat.predict(X_test_data)
y_train_pred_data = cat.predict(X_train_data)

# %%
# RMSE on training data
train_rmse = mean_squared_error(y_train_data, y_train_pred_data) ** 0.5  

# RMSE on test data
test_rmse  = mean_squared_error(y_test_data, y_test_pred_data) ** 0.5

# %%
# Print train RMSE
print(f"Mean Squared Train Error: {train_rmse:.2f}")
# Print R² score for train data
print("R2 Cat Train:", f"{r2_score(y_train_data, y_train_pred_data):.5f}")
# Out:
# Mean Squared Train Error: 68784.50
# R2 Cat Train: 0.96379

# %%
# Print test RMSE
print(f"Mean Squared Test Error: {test_rmse:.2f}")
# Print R² score for test data
print("R2 Cat Test:", f"{r2_score(y_test_data, y_test_pred_data):.5f}")
# Out:
# Mean Squared Test Error: 125663.72
# R2 Cat Test: 0.89554

# %% [markdown]
# <span style="color:#B3FFB3"> Dropping Data

# %% [markdown]
# <span style="color:#E6B3FF"> Linear Regression

# %%
# Create and train a linear regression model on the cleaned dataset
linear_model = LinearRegression()
linear_model.fit(X_train_drop, y_train_drop)  # fit model to training data
# Out:
# LinearRegression()

# %%
# Make predictions with the trained linear regression model on cleaned data
y_test_pred_drop = linear_model.predict(X_test_drop)     # test set predictions
y_train_pred_drop = linear_model.predict(X_train_drop)   # train set predictions

# %%
# Evaluate linear regression performance on cleaned data using R²
print("R2 Linear Regression Train:", f"{r2_score(y_train_drop, y_train_pred_drop):.5f}")  # train set
print("R2 Linear Regression Test:", f"{r2_score(y_test_drop, y_test_pred_drop):.5f}")    # test set
# Out:
# R2 Linear Regression Train: 0.69740
# R2 Linear Regression Test: 0.70614

# %%
# Display the predicted house prices for the test set (cleaned data)
y_test_pred_drop
# Out:
# array([ 556754.04676756,   66164.85996003, 1338372.40246925, ...,
#         892530.48955243,  303145.28577915,  533470.38378708])

# %%
# Display the actual house prices for the test set (cleaned data)
y_test_drop
# Out:
# 14664    454800.0
# 3767      84000.0
# 11599    850000.0
# 7791     440000.0
# 19461    550000.0
#            ...
# 8281     616000.0
# 18237    591000.0
# 12744    975000.0
# 16461    254000.0
# 14729    620000.0
# Name: price, Length: 4288, dtype: float64

# %% [markdown]
# <span style="color:#E6B3FF"> ADAboosting

# %%
# Create and train an AdaBoost regressor on the cleaned dataset
abc = AdaBoostRegressor(n_estimators=100, learning_rate=0.05, random_state=42)
model = abc.fit(X_train_drop, y_train_drop)  # fit model to training data

# %%
# Make predictions with the trained AdaBoost model on cleaned data
y_test_pred_drop = model.predict(X_test_drop)     # test set predictions
y_train_pred_drop = model.predict(X_train_drop)   # train set predictions

# %%
# Evaluate AdaBoost model performance on cleaned data using R²
print("R2 ADAregressor Train:", f"{r2_score(y_train_drop, y_train_pred_drop):.5f}")  # train set
print("R2 ADAregressor Test:", f"{r2_score(y_test_drop, y_test_pred_drop):.5f}")    # test set
# Out:
# R2 ADAregressor Train: 0.70671
# R2 ADAregressor Test: 0.68257

# %% [markdown]
# <span style="color:#E6B3FF"> XGboosting

# %%
# Create and train an XGBoost regressor on the cleaned dataset
xgb_reg = xgb.XGBRegressor()
xgb_reg.fit(X_train_drop, y_train_drop)  # fit model to training data
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
# Make predictions with the trained XGBoost model on cleaned data
y_test_pred_drop = xgb_reg.predict(X_test_drop)     # test set predictions
y_train_pred_drop = xgb_reg.predict(X_train_drop)   # train set predictions

# %%
# Evaluate XGBoost model performance on cleaned data using R²
print("R2 XGboost Train:", f"{r2_score(y_train_drop, y_train_pred_drop):.5f}")  # train set
print("R2 XGboost Test:", f"{r2_score(y_test_drop, y_test_pred_drop):.5f}")    # test set
# Out:
# R2 XGboost Train: 0.97673
# R2 XGboost Test: 0.89680

# %% [markdown]
# <span style="color:#E6B3FF"> Random Forest

# %%
# Create and train a Random Forest regressor on the cleaned dataset
rf_regressor = RandomForestRegressor(n_estimators=120, random_state=42)
rf_regressor.fit(X_train_drop, y_train_drop)  # fit model to training data
# Out:
# RandomForestRegressor(n_estimators=120, random_state=42)

# %%
# Predict with Random Forest and calculate Mean Squared Error (MSE) on cleaned data
y_test_pred_drop = rf_regressor.predict(X_test_drop)        # test set predictions
mse_test = mean_squared_error(y_test_drop, y_test_pred_drop)  # test set MSE

y_train_pred_drop = rf_regressor.predict(X_train_drop)      # train set predictions
mse_train = mean_squared_error(y_train_drop, y_train_pred_drop)  # train set MSE

# %%
# Display training error and performance for Random Forest (cleaned data)
print(f"Mean Squared Error: {mse_train:.2f}")                        # training MSE
print("R2 Random Forest Train:", f"{r2_score(y_train_drop, y_train_pred_drop):.5f}")  # training R²
# Out:
# Mean Squared Error: 2391235579.01
# R2 Random Forest Train: 0.98208

# %%
# Display test error and performance for Random Forest (cleaned data)
print(f"Mean Squared Error: {mse_test:.2f}")                     # test set MSE
print("R2 Random Forest Test:", f"{r2_score(y_test_drop, y_test_pred_drop):.5f}")  # test set R²
# Out:
# Mean Squared Error: 15992427088.73
# R2 Random Forest Test: 0.88639

# %% [markdown]
# <span style="color:#E6B3FF"> Gradient Boosting

# %%
# Create and train a Gradient Boosting regressor on the cleaned dataset
gbr = GradientBoostingRegressor(
    loss='absolute_error',   # use MAE as loss function
    learning_rate=0.1,
    n_estimators=300,
    max_depth=1,
    max_features=5,
    random_state=42
)
gbr.fit(X_train_drop, y_train_drop)  # fit model to training data
# Out:
# GradientBoostingRegressor(loss='absolute_error', max_depth=1, max_features=5,
#                           n_estimators=300, random_state=42)

# %%
# Make predictions with the trained Gradient Boosting model on cleaned data
y_test_pred_drop = gbr.predict(X_test_drop)     # test set predictions
y_train_pred_drop = gbr.predict(X_train_drop)   # train set predictions

# %%
# Compute Root Mean Squared Error (RMSE) for Gradient Boosting on cleaned data
train_rmse = mean_squared_error(y_train_drop, y_train_pred_drop) ** 0.5  # training RMSE
test_rmse  = mean_squared_error(y_test_drop, y_test_pred_drop) ** 0.5   # test RMSE

# %%
# Evaluate Gradient Boosting performance on cleaned data using R²
print("R2 Gradient Train:", f"{r2_score(y_train_drop, y_train_pred_drop):.5f}")  # train set
print("R2 Gradient Test:", f"{r2_score(y_test_drop, y_test_pred_drop):.5f}")    # test set
# Out:
# R2 Gradient Train: 0.69062
# R2 Gradient Test: 0.69180

# %% [markdown]
# <span style="color:#E6B3FF"> CatBoost

# %%
# Initialize CatBoost regressor
cat = CatBoostRegressor(verbose=0, random_state=42)

# Fit model on training data
cat.fit(X_train_drop, y_train_drop)

# %%
# Predict on test set
y_test_pred_drop = cat.predict(X_test_drop)

# Predict on train set
y_train_pred_drop = cat.predict(X_train_drop)

# %%
# Compute RMSE for training set
train_rmse = mean_squared_error(y_train_drop, y_train_pred_drop) ** 0.5

# Compute RMSE for test set
test_rmse  = mean_squared_error(y_test_drop, y_test_pred_drop) ** 0.5

# %%
# Print RMSE for training set
print(f"Mean Squared Train Error: {train_rmse:.2f}")

# Print R² score for training set
print("R2 Cat Train:", f"{r2_score(y_train_drop, y_train_pred_drop):.5f}")
# Out:
# Mean Squared Train Error: 68536.94
# R2 Cat Train: 0.96480

# %%
# Print RMSE for test set
print(f"Mean Squared Test Error: {test_rmse:.2f}")

# Print R² score for test set
print("R2 Cat Test:", f"{r2_score(y_test_drop, y_test_pred_drop):.5f}")
# Out:
# Mean Squared Test Error: 111021.33
# R2 Cat Test: 0.91244

# %% [markdown]
# - Linear Regression shows the weakest performance.
# - XGBoost and Random Forest achieve the best performance.
# - With further analysis we also found one more models that are catboost these are also having similar results but catboost having a bit more beter r2 and mse scores

# %% [markdown]
# ##### <span style="color:#FFD600">Improving the Model:

# %% [markdown]
# <span style="color:#FFE5B4">
# * On the data side (cleaning, dropping or combining multicollinearity features, dealing with outliers, feature selection - identify which features are truly useful for predicting the target -, normalization, standardization, etc.)

# %% [markdown]
# <span style="color:#FFE5B4">
# * On the model side (selecting other models/ trying additional algorithms, hyperparameter tuning)

# %%
# Extract the month from the 'date' column and create a new 'month' column
country_houses["month"] = country_houses["date"].dt.month

# Display the new 'month' column
country_houses["month"]
# Out:
# 0        10
# 1        12
# 2         2
# 3        12
# 4         2
#          ..
# 21608     5
# 21609     2
# 21610     6
# 21611     1
# 21612    10
# Name: month, Length: 21613, dtype: int32

# %%
# Count how many records fall in each month
country_houses["month"].value_counts()
# Out:
# month
# 5     2414
# 4     2231
# 7     2211
# 6     2180
# 8     1940
# 10    1878
# 3     1875
# 9     1774
# 12    1471
# 11    1411
# 2     1250
# 1      978
# Name: count, dtype: int64

# %%
country_houses
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000.0         3       2.50         1530
# 21609  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21610  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21611   291310100 2015-01-16  400000.0         3       2.50         1600
# 21612  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# ...

# %%
# Features and target for final modeling
X_final = country_houses.drop(columns=["price", "id", "date"])  # predictors
y_final = country_houses["price"]                               # target variable

# %%
# Split the final dataset into training (80%) and test (20%) sets
X_train_final, X_test_final, y_train_final, y_test_final = train_test_split(X_final, y_final, test_size=0.2, random_state=42)

# %%
# Initialize CatBoost regressor
cat = CatBoostRegressor(verbose=0, random_state=42)

# Fit model on training data
cat.fit(X_train_final, y_train_final)

# %%
# Make predictions with the trained XGBoost model on the full dataset
y_test_pred_final = cat.predict(X_test_final)     # test set predictions
y_train_pred_final = cat.predict(X_train_final)   # train set predictions

# %%
# Compute RMSE for training set
train_rmse = mean_squared_error(y_train_final, y_train_pred_final) ** 0.5

# Compute RMSE for test set
test_rmse  = mean_squared_error(y_test_final, y_test_pred_final) ** 0.5

# %%
print(f"Mean Squared Train Error: {train_rmse:.2f}")
print("R2 CatBoost Train:",f"{r2_score(y_train_final, y_train_pred_final):.5f}")  # train set
# Out:
# Mean Squared Train Error: 66879.13
# R2 CatBoost Train: 0.96576

# %%
print(f"Mean Squared Train Error: {test_rmse:.2f}")
print("R2 CatBoost Test:", f"{r2_score(y_test_final, y_test_pred_final):.5f}")    # test set
# Out:
# Mean Squared Train Error: 124742.05
# R2 CatBoost Test: 0.89707

# %% [markdown]
# ##### <span style="color:#FFD600"> Feature Importance:

# %% [markdown]
# <span style="color:#FFE5B4">
# - From the best-performing model, extract feature importance;

# %% [markdown]
# <span style="color:#FFE5B4">
# - Answer: Which features most strongly influence house prices?

# %% [markdown]
# <span style="color:#E6B3FF"> CatBoost

# %%
# Create a DataFrame showing feature importances from the XGBoost model
feature_importances = pd.DataFrame({'Feature': X_final.columns,'Importance': cat.get_feature_importance()}).sort_values(by='Importance', ascending=False)

# Display the features ranked by importance
print(feature_importances)
# Out:
#           Feature  Importance
# 14            lat   28.273789
# 2     sqft_living   17.946818
# 8           grade   13.488922
# 15           long   11.407131
# 16  sqft_living15    4.464191
# 5      waterfront    3.751782
# 11       yr_built    3.449396
# 13        zipcode    3.111245
# 6            view    3.090641
# 9      sqft_above    2.889917
# 1       bathrooms    1.938235
# 3        sqft_lot    1.418834
# 10  sqft_basement    1.184117
# 17     sqft_lot15    1.047168
# 7       condition    0.806255
# 18          month    0.692911
# 12   yr_renovated    0.491809
# 4          floors    0.328035
# 0        bedrooms    0.218805

# %% [markdown]
# The CatBoost analysis indicates that lat (latitude coordinate), sqft_living (interior living area) and grade (overall grade given to the house) are the strongest predictors of house prices whereas variables like floors or bedrooms have little impact.
